# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import plotnine as p9

plt.style.use('ggplot') # set the theme for plots
mpl.rcParams['figure.figsize'] = (10,8)
datadir = "CollegeScorecard_Raw_Data_03142022"

import warnings
warnings.filterwarnings('ignore')

# %%
# read in the 2009 data
COL = pd.read_csv(datadir + '/MERGED2015_16_PP.csv')

# %%
loc =['UNITID',"LATITUDE","LONGITUDE"]

# %%
category=["academic, admission, completion, cost, earnings,repayment,student "]

# %%
COL.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  COUNT_WNE_MALE1_P8  \
# 0     AL       35762           NaN      NaN     NaN  ...                 NaN
# 1     AL  35294-0110           NaN      NaN     NaN  ...                 NaN
# 2     AL  36117-3553           NaN      NaN     NaN  ...                 NaN
# 3     AL       35899           NaN      NaN     NaN  ...                 NaN
# 4     AL  36104-0271           NaN      NaN     NaN  ...                 NaN
#
# ...

# %%
COL.shape
# Out:
# (7666, 2989)

# %%
col_dna = COL.dropna(thresh=3000,axis=1) # axis =1 drop column
col_dna.shape
# Out:
# (7666, 1550)

# %%
numeric_bool = ((col_dna.dtypes=='int64') + (col_dna.dtypes=='float64'))
numeric_col = list(numeric_bool.index[numeric_bool])
col_dna_numeric = col_dna[numeric_col]
col_dna_numeric.shape
# Out:
# (7666, 340)

# %%
col_dna_numeric.keys()
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'SCH_DEG', 'MAIN', 'NUMBRANCH', 'PREDDEG',
#        'HIGHDEG', 'CONTROL', 'ST_FIPS',
#        ...
#        'FTFTPCTPELL', 'FTFTPCTFLOAN', 'UG12MN', 'SCUGFFN', 'PPLUS_PCT_LOW',
#        'PPLUS_PCT_HIGH', 'BOOKSUPPLY', 'ROOMBOARD_OFF', 'OTHEREXPENSE_OFF',
#        'OTHEREXPENSE_FAM'],
#       dtype='object', length=340)

# %%
col_dna_numeric.head()
# Out:
#    UNITID    OPEID  OPEID6  SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  \
# 0  100654   100200    1002      3.0     1          1        3        4
# 1  100663   105200    1052      3.0     1          1        3        4
# 2  100690  2503400   25034      3.0     1          1        3        4
# 3  100706   105500    1055      3.0     1          1        3        4
# 4  100724   100500    1005      3.0     1          1        3        4
#
#    CONTROL  ST_FIPS  ...  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN  SCUGFFN  \
# 0        1        1  ...       0.7571        0.8063   4549.0   1198.0
# 1        1        1  ...       0.3799        0.5387  13465.0   1719.0
# 2        2        1  ...       0.7778        0.8889    401.0      9.0
# 3        1        1  ...       0.2689        0.4370   6540.0    714.0
# 4        1        1  ...       0.8146        0.8137   5456.0   1068.0
#
#    PPLUS_PCT_LOW  PPLUS_PCT_HIGH  BOOKSUPPLY  ROOMBOARD_OFF  OTHEREXPENSE_OFF  \
# ...

# %%
col_dna_numeric.fillna(col_dna_numeric.mean())
# Out:
#         UNITID    OPEID  OPEID6   SCH_DEG  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  \
# 0       100654   100200    1002  3.000000     1          1        3        4
# 1       100663   105200    1052  3.000000     1          1        3        4
# 2       100690  2503400   25034  3.000000     1          1        3        4
# 3       100706   105500    1055  3.000000     1          1        3        4
# 4       100724   100500    1005  3.000000     1          1        3        4
# ...        ...      ...     ...       ...   ...        ...      ...      ...
# 7661  48154401  4220901   42209  1.000000     0          2        0        0
# 7662  48387801  4223701   42237  1.000000     0          2        0        0
# 7663  48400201  4228101   42281  1.000000     0          2        0        0
# 7664  48414501  4232401   42324  2.000000     0          2        0        0
# 7665  48621101  4215601   42156  1.892619     0          1        0        0
#
# ...

# %%
print((COL['ADM_RATE'].isna()).sum())
print((COL['SATVRMID'].isna()).sum())
print((COL['ADM_RATE_ALL'].isna()).sum())
# Out:
# 4423
# 5936
# 4166

# %%
col_dtypes = dict(col_dna.dtypes.replace(np.dtype('int64'),np.dtype('float64'))) # make the dtypes floats
# col_dtypes['UNITID'] = np.dtype('int64') # convert the UNITID back to int
# vars_interest = ['ADM_RATE','UGDS','TUITIONFEE_IN','TUITIONFEE_OUT','MN_EARN_WNE_P10'] # Include these vars
# col_dtypes.update({a: np.dtype('float64') for a in vars_interest}) # make them floats
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d5dd5b75f4e1> in <module>
# ----> 1 col_dtypes = dict(col_dna.dtypes.replace(np.dtype('int64'),np.dtype('float64'))) # make the dtypes floats
#       2 # col_dtypes['UNITID'] = np.dtype('int64') # convert the UNITID back to int
#       3 # vars_interest = ['ADM_RATE','UGDS','TUITIONFEE_IN','TUITIONFEE_OUT','MN_EARN_WNE_P10'] # Include these vars
#       4 # col_dtypes.update({a: np.dtype('float64') for a in vars_interest}) # make them floats
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4955         method: str | lib.NoDefault = lib.no_default,
#    4956     ):
# -> 4957         return super().replace(
#    4958             to_replace=to_replace,
#    4959             value=value,
#
# ...
