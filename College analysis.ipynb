# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import plotnine as p9

plt.style.use('ggplot') # set the theme for plots
mpl.rcParams['figure.figsize'] = (10,8)
datadir = "./CollegeScorecard_Raw_Data_03142022"

import warnings
warnings.filterwarnings('ignore')

# %%
# read in the 2009 data
COL = pd.read_csv(datadir + '/Most-Recent-Cohorts-Institution.csv')
COL = COL.replace("PrivacySuppressed", np.nan)

# %%
interest = ["UNITID","OPEID","OPEID6","INSTNM","CITY",            
            "STABBR",             
            "ZIP",                
            "MAIN",               
            "NUMBRANCH",          
            "PREDDEG",            
            "HIGHDEG",            
            "CONTROL",            
            "ST_FIPS",            
            "REGION",            
            "ADM_RATE",          
            "UGDS",               
            "TUITIONFEE_IN",      
            "TUITIONFEE_OUT",     
            "MN_EARN_WNE_P10",    
            "ICLEVEL"]

# %%
df = COL[interest]
df['MN_EARN_WNE_P10'] = df['MN_EARN_WNE_P10'].astype(float)

# %%
df
# Out:
#         UNITID    OPEID  OPEID6                                    INSTNM  \
# 0       100654   100200    1002                  Alabama A & M University
# 1       100663   105200    1052       University of Alabama at Birmingham
# 2       100690  2503400   25034                        Amridge University
# 3       100706   105500    1055       University of Alabama in Huntsville
# 4       100724   100500    1005                  Alabama State University
# ...        ...      ...     ...                                       ...
# 6689  48511113   157115    1571        Georgia Military College - Eastman
# 6690  48616901  4204801   42048  American College of Barbering - Florence
# 6691  49005401  4182601   41826      HCI College - Fort Lauderdale Campus
# 6692  49146401  4227001   42270          ABC Adult School - Cabrillo Lane
# 6693  49175601  4270001   42700           Urban Barber College - San Jose
#
#                  CITY STABBR         ZIP  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  \
# 0              Normal     AL       35762     1          1        3        4
# 1          Birmingham     AL  35294-0110     1          1        3        4
# 2          Montgomery     AL  36117-3553     1          1        2        4
# 3          Huntsville     AL       35899     1          1        3        4
# 4          Montgomery     AL  36104-0271     1          1        3        4
# ...               ...    ...         ...   ...        ...      ...      ...
# 6689          Eastman     GA   310236109     0         14        0        0
# 6690         Florence     KY   410421801     0          2        0        0
# 6691  Fort Lauderdale     FL       33309     0          2        0        0
# 6692         Cerritos     CA   907037748     0          2        0        0
# 6693         San Jose     CA       95133     0          2        0        0
#
#       CONTROL  ST_FIPS  REGION  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0           1        1       5    0.9175   5271.0        10024.0
# 1           1        1       5    0.7366  13328.0         8568.0
# 2           2        1       5       NaN    365.0         6950.0
# 3           1        1       5    0.8257   7785.0        11122.0
# 4           1        1       5    0.9690   3750.0        11068.0
# ...       ...      ...     ...       ...      ...            ...
# 6689        1       13       5       NaN      NaN         6165.0
# 6690        3       21       5       NaN      NaN            NaN
# 6691        3       12       5       NaN      NaN        19404.0
# 6692        1        6       8       NaN      NaN            NaN
# 6693        3        6       8       NaN      NaN            NaN
#
#       TUITIONFEE_OUT  MN_EARN_WNE_P10  ICLEVEL
# 0            18634.0          35500.0        1
# 1            20400.0          48400.0        1
# 2             6950.0          47600.0        1
# 3            23518.0          52000.0        1
# 4            19396.0          30600.0        1
# ...              ...              ...      ...
# 6689             NaN              NaN        1
# 6690             NaN              NaN        3
# 6691             NaN              NaN        2
# 6692             NaN              NaN        3
# 6693             NaN              NaN        3
#
# [6694 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6694 entries, 0 to 6693
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   UNITID           6694 non-null   int64
#  1   OPEID            6694 non-null   int64
#  2   OPEID6           6694 non-null   int64
#  3   INSTNM           6694 non-null   object
#  4   CITY             6694 non-null   object
#  5   STABBR           6694 non-null   object
#  6   ZIP              6694 non-null   object
#  7   MAIN             6694 non-null   int64
#  8   NUMBRANCH        6694 non-null   int64
#  9   PREDDEG          6694 non-null   int64
#  10  HIGHDEG          6694 non-null   int64
#  11  CONTROL          6694 non-null   int64
#  12  ST_FIPS          6694 non-null   int64
#  13  REGION           6694 non-null   int64
#  14  ADM_RATE         1988 non-null   float64
#  15  UGDS             5902 non-null   float64
#  16  TUITIONFEE_IN    3836 non-null   float64
#  17  TUITIONFEE_OUT   3574 non-null   float64
#  18  MN_EARN_WNE_P10  4649 non-null   float64
#  19  ICLEVEL          6694 non-null   int64
# dtypes: float64(5), int64(11), object(4)
# memory usage: 1.0+ MB

# %%
df_new = df.fillna(df.mean())

# %%
df_new
# Out:
#         UNITID    OPEID  OPEID6                                    INSTNM  \
# 0       100654   100200    1002                  Alabama A & M University
# 1       100663   105200    1052       University of Alabama at Birmingham
# 2       100690  2503400   25034                        Amridge University
# 3       100706   105500    1055       University of Alabama in Huntsville
# 4       100724   100500    1005                  Alabama State University
# ...        ...      ...     ...                                       ...
# 6689  48511113   157115    1571        Georgia Military College - Eastman
# 6690  48616901  4204801   42048  American College of Barbering - Florence
# 6691  49005401  4182601   41826      HCI College - Fort Lauderdale Campus
# 6692  49146401  4227001   42270          ABC Adult School - Cabrillo Lane
# 6693  49175601  4270001   42700           Urban Barber College - San Jose
#
#                  CITY STABBR         ZIP  MAIN  NUMBRANCH  PREDDEG  HIGHDEG  \
# 0              Normal     AL       35762     1          1        3        4
# 1          Birmingham     AL  35294-0110     1          1        3        4
# 2          Montgomery     AL  36117-3553     1          1        2        4
# 3          Huntsville     AL       35899     1          1        3        4
# 4          Montgomery     AL  36104-0271     1          1        3        4
# ...               ...    ...         ...   ...        ...      ...      ...
# 6689          Eastman     GA   310236109     0         14        0        0
# 6690         Florence     KY   410421801     0          2        0        0
# 6691  Fort Lauderdale     FL       33309     0          2        0        0
# 6692         Cerritos     CA   907037748     0          2        0        0
# 6693         San Jose     CA       95133     0          2        0        0
#
#       CONTROL  ST_FIPS  REGION  ADM_RATE          UGDS  TUITIONFEE_IN  \
# 0           1        1       5  0.917500   5271.000000   10024.000000
# 1           1        1       5  0.736600  13328.000000    8568.000000
# 2           2        1       5  0.689655    365.000000    6950.000000
# 3           1        1       5  0.825700   7785.000000   11122.000000
# 4           1        1       5  0.969000   3750.000000   11068.000000
# ...       ...      ...     ...       ...           ...            ...
# 6689        1       13       5  0.689655   2559.643511    6165.000000
# 6690        3       21       5  0.689655   2559.643511   15761.590459
# 6691        3       12       5  0.689655   2559.643511   19404.000000
# 6692        1        6       8  0.689655   2559.643511   15761.590459
# 6693        3        6       8  0.689655   2559.643511   15761.590459
#
#       TUITIONFEE_OUT  MN_EARN_WNE_P10  ICLEVEL
# 0       18634.000000     35500.000000        1
# 1       20400.000000     48400.000000        1
# 2        6950.000000     47600.000000        1
# 3       23518.000000     52000.000000        1
# 4       19396.000000     30600.000000        1
# ...              ...              ...      ...
# 6689    19301.696419     40435.297914        1
# 6690    19301.696419     40435.297914        3
# 6691    19301.696419     40435.297914        2
# 6692    19301.696419     40435.297914        3
# 6693    19301.696419     40435.297914        3
#
# [6694 rows x 20 columns]

# %%
df_new['Year'] = pd.Period('2010',freq='Y')

# %%
def read_cs_data(year,col_dtypes,datadir):
    """read a CollegeScorecard dataframe"""
    nextyr = str(int(year) + 1)[-2:]
    filename = datadir + '/MERGED{}_{}_PP.csv'.format(year,nextyr)
    col = pd.read_csv(filename,na_values='PrivacySuppressed',
                      dtype=col_dtypes,usecols=col_dtypes.keys())
    col['Year'] = pd.Period(str(int(year) + 1),freq='Y')
    return col

# %%
col = pd.concat((read_cs_data(str(y),col_dtypes,datadir) for y in range(1996,2017)))
col = col.set_index(['UNITID','Year'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-a35946092708> in <module>
# ----> 1 col = pd.concat((read_cs_data(str(y),col_dtypes,datadir) for y in range(1996,2017)))
#       2 col = col.set_index(['UNITID','Year'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     344     ValueError: Indexes have overlapping values: ['a']
#     345     """
# --> 346     op = _Concatenator(
#     347         objs,
#     348         axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     398             objs = [objs[k] for k in keys]
#     399         else:
# --> 400             objs = list(objs)
#     401
#     402         if len(objs) == 0:
#
# <ipython-input-148-a35946092708> in <genexpr>(.0)
# ----> 1 col = pd.concat((read_cs_data(str(y),col_dtypes,datadir) for y in range(1996,2017)))
#       2 col = col.set_index(['UNITID','Year'])
#
# <ipython-input-147-b7be5854a2ce> in read_cs_data(year, col_dtypes, datadir)
#       3     nextyr = str(int(year) + 1)[-2:]
#       4     filename = datadir + '/MERGED{}_{}_PP.csv'.format(year,nextyr)
# ----> 5     col = pd.read_csv(filename,na_values='PrivacySuppressed',
#       6                       dtype=col_dtypes,usecols=col_dtypes.keys())
#       7     col['Year'] = pd.Period(str(int(year) + 1),freq='Y')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     678     kwds.update(kwds_defaults)
#     679
# --> 680     return _read(filepath_or_buffer, kwds)
#     681
#     682
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     931
#     932         self.handles: IOHandles | None = None
# --> 933         self._engine = self._make_engine(f, self.engine)
#     934
#     935     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1229
#    1230         try:
# -> 1231             return mapping[engine](f, **self.options)
#    1232         except Exception:
#    1233             if self.handles is not None:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      72             kwds.pop(key, None)
#      73
# ---> 74         kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
#      75         self._reader = parsers.TextReader(src, **kwds)
#      76
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in ensure_dtype_objs(dtype)
#     416         return {k: pandas_dtype(dtype[k]) for k in dtype}
#     417     elif dtype is not None:
# --> 418         return pandas_dtype(dtype)
#     419     return dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\common.py in pandas_dtype(dtype)
#    1790         return npdtype
#    1791     elif npdtype.kind == "O":
# -> 1792         raise TypeError(f"dtype '{dtype}' not understood")
#    1793
#    1794     return npdtype
#
# TypeError: dtype 'UNITID               int64
# OPEID              float64
# OPEID6             float64
# INSTNM              object
# CITY                object
# STABBR              object
# ZIP                 object
# MAIN               float64
# NUMBRANCH          float64
# PREDDEG            float64
# HIGHDEG            float64
# CONTROL            float64
# ST_FIPS            float64
# REGION             float64
# ADM_RATE           float64
# UGDS               float64
# TUITIONFEE_IN      float64
# TUITIONFEE_OUT     float64
# MN_EARN_WNE_P10    float64
# ICLEVEL            float64
# dtype: object' not understood
